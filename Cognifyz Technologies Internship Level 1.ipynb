# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Level 1

# %% [markdown]
# # Task 1
#  Task:  Data Exploration and Preprocessing
#  Explore the dataset and identify the number
#  of rows and columns.
#  Check for missing values in each column and
#  handle them accordingly.
#  Perform data type conversion if necessary.
#  Analyze the distribution of the target variable
#  ("Aggregate rating") and identify any class
#  imbalances

# %%
df = pd.read_csv('Dataset .csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df = df.rename(columns={df.columns[19]: 'Rating'})
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# Get the number of rows and columns
print(f"Number of rows: {df.shape[0]}")
print(f"Number of colus: {df.shape[1]}")
# Out:
# Number of rows: 9551
# Number of colus: 21

# %%
# Check for missing values in each column
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating                  0
# Votes                   0
# dtype: int64

# %%
# Check the data types of each column
print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating                   object
# Votes                     int64
# dtype: object

# %%
# Convert the 'column_name' column to a specific data type (e.g., object)
df['Country'] = df['Locality'].astype(object)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# Analyze the distribution of the target variable
print("Distribution of the target variable:")
print(df['Aggregate rating'].value_counts())
# Out:
# Distribution of the target variable:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
target = "Aggregate rating"

# %%
print(df[target].describe())
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df[target])
plt.title("Box Plot")
plt.xlabel("Aggregate rating")
plt.show()

# %%
# Identify class imbalances
plt.hist(df['Aggregate rating'], bins=10)
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.title('Target Variable Distribution')
plt.show()

# %% [markdown]
# # Task 2
#  Task:  Descriptive Analysis
#  Calculate basic statistical measures (mean,
#  median, standard deviation, etc.) for numerical
#  columns.
#  Explore the distribution of categorical
#  variables like "Country Code," "City," and
#  "Cuisines."
#  Identify the top cuisines and cities with the
#  highest number of restaurants

# %%
# Calculate basic statistical measures for numerical columns
numerical_cols = df.select_dtypes(include=[np.number]).columns
print("Basic Statistical Measures:")
for col in numerical_cols:
    print(f"Column: {col}")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Standard Deviation: {df[col].std():.2f}")
    print(f"Minimum: {df[col].min():.2f}")
    print(f"Maximum: {df[col].max():.2f}")
    print("")
# Out:
# Basic Statistical Measures:
# Column: Restaurant ID
# Mean: 9051128.35
# Median: 6004089.00
# Standard Deviation: 8791521.28
# Minimum: 53.00
# Maximum: 18500652.00
#
# Column: Country Code
# Mean: 18.37
# Median: 1.00
# Standard Deviation: 56.75
# Minimum: 1.00
# Maximum: 216.00
#
# Column: Longitude
# Mean: 64.13
# Median: 77.19
# Standard Deviation: 41.47
# Minimum: -157.95
# Maximum: 174.83
#
# Column: Latitude
# Mean: 25.85
# Median: 28.57
# Standard Deviation: 11.01
# Minimum: -41.33
# Maximum: 55.98
#
# Column: Average Cost for two
# Mean: 1199.21
# Median: 400.00
# Standard Deviation: 16121.18
# Minimum: 0.00
# Maximum: 800000.00
#
# Column: Price range
# Mean: 1.80
# Median: 2.00
# Standard Deviation: 0.91
# Minimum: 1.00
# Maximum: 4.00
#
# Column: Aggregate rating
# Mean: 2.67
# Median: 3.20
# Standard Deviation: 1.52
# Minimum: 0.00
# Maximum: 4.90
#
# Column: Votes
# Mean: 156.91
# Median: 31.00
# Standard Deviation: 430.17
# Minimum: 0.00
# Maximum: 10934.00

# %%
# Explore the distribution of categorical variables
categorical_cols = df.select_dtypes(include=[object]).columns
print("Categorical Variable Distribution:")
for col in categorical_cols:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("")
# Out:
# Categorical Variable Distribution:
# Column: Restaurant Name
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64
#
# Column: City
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64
#
# Column: Address
# Address
# Dilli Haat, INA, New Delhi                                                               11
# ...

# %%
# Identify the top cuisines and cities with the highest number of restaurants
print("Top Cuisines:")
top_cuisines = df['Cuisines'].value_counts().head(10)
print(top_cuisines)
# Out:
# Top Cuisines:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
print("Top Cities:")
top_cities = df['City'].value_counts().head(10)
print(top_cities)
# Out:
# Top Cities:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
# Visualize the distribution of categorical variables
plt.figure(figsize=(10, 6))
sns.countplot(x="Cuisines", data=df)
plt.title("Distribution of Cuisines")
plt.xlabel("Cuisine")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="City", data=df)
plt.title("Distribution of Cities")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #  Task 3
# Task:  Geospatial Analysis
#  Visualize the locations of restaurants on a
#  map using latitude and longitude
#  information.
#  Analyze the distribution of restaurants
#  across different cities or countries.
#  Determine if there is any correlation
#  between the restaurant's location and its
#  rating

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

# %%
# Create a Folium map to visualize restaurant locations
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=4)

# %%
# Add markers for each restaurant
marker_cluster = MarkerCluster().add_to(m)
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Restaurant Name']).add_to(marker_cluster)

# %%
# Save the map to an HTML file
m.save('Dataset_map.html')

# %%
import webbrowser
webbrowser.open('Dataset_map.html')
# Out:
# True

# %%
# Analyze the distribution of restaurants across different cities or countries
print("Distribution of Restaurants across Cities:")
city_counts = df['City'].value_counts()
print(city_counts)
# Out:
# Distribution of Restaurants across Cities:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
print("Distribution of Restaurants across Countries:")
country_counts = df['Country Code'].value_counts()
print(country_counts)
# Out:
# Distribution of Restaurants across Countries:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
# Visualize the distribution of restaurants across cities and countries
plt.figure(figsize=(10, 6))
sns.countplot(x="City", data=df)
plt.title("Distribution of Restaurants across Cities")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Country Code", data=df)
plt.title("Distribution of Restaurants across Countries")
plt.xlabel("Country Code")
plt.ylabel("Count")
plt.show()

# %%
latitude_corr, _ = spearmanr(df['Latitude'], df['Rating'].rank())
print(f'Correlation between Latitude and Rating: {latitude_corr:.2f}')
# Out:
# Correlation between Latitude and Rating: -0.10

# %%
# Calculate the correlation between Longitude and Rating
longitude_corr, _ = spearmanr(df['Longitude'], df['Rating'].rank())
print(f'Correlation between Longitude and Rating: {longitude_corr:.2f}')
# Out:
# Correlation between Longitude and Rating: -0.11

# %%
# Group by city and count the number of restaurants
city_counts = df.groupby('City')['Restaurant Name'].count()
# Group by country and count the number of restaurants
country_counts = df.groupby('Country')['Restaurant Name'].count()
print("Distribution of restaurants by country:")
print(country_counts)
print("Distribution of restaurants by city:")
print(city_counts)
# Out:
# Distribution of restaurants by country:
# Country
#  ILD Trade Centre Mall, Sohna Road     2
# 12th Square Building, Banjara Hills    1
# A Hotel, Gurdev Nagar                  1
# ARSS Mall, Paschim Vihar               1
# Aaya Nagar                             1
#                                       ..
# ibis New Delhi, Aerocity               2
# �ayyolu                                1
# �guas Claras                           3
# �ukurambar                             1
# ��mitk�_y                              1
# Name: Restaurant Name, Length: 1208, dtype: int64
# Distribution of restaurants by city:
# City
# Abu Dhabi          20
# Agra               20
# Ahmedabad          21
# Albany             20
# Allahabad          20
#                    ..
# Weirton             1
# Wellington City    20
# Winchester Bay      1
# Yorkton             1
# ��stanbul          14
# Name: Restaurant Name, Length: 141, dtype: int64

# %% [markdown]
# # Thanking You
